# %%
import pandas as pd
import numpy as np
# Create a simple dataset
data = {
    "Name": ['Ajit Doval', 'Hamza Ali', 'Jassi Singh', 'Jameel Jamali'], 
    "Marks": [90, 95, 92, 99] 
    }
df = pd.DataFrame(data)
# Replace 'NA' with np.nan
df.replace('NA', np.nan, inplace = True)
# Save the dataset
df.to_csv("data.csv", index  = False)
# Load it back
df = pd.read_csv("data.csv")
pd.set_option('display.max_rows', None)
# access specific columns
df.Name
df[['Name', 'Marks']]
# see all the column names
df.columns
# access rows by integer location
df.iloc[0]
df.iloc[[0, 1]]
# access rows and columns using integer location- (row, column)
df.iloc[[0, 2], [0,1]]
# using loc
df.loc[[0, 3], 'Name']
df.loc[[0, 3], ['Name', 'Marks']]
# Filter marks
df[df["Marks"] > 90]
# reverse selection
df.iloc[::-1]
# select last 3 rows
df.iloc[-3:]
# multi-condition filter
df["Honor roll"] = df["Marks"] >= 95
df.loc[(df["Marks"] > 90) & (df["Honor roll"] == True)]
# setting the index
df.set_index("Name", inplace = True)
df.index
df.loc["Ajit Doval", 'Marks']
df.reset_index(inplace = True)
# Anyone who has 'J' in their name
df[df["Name"].str.contains('J')]
# add new rows
new_row = pd.DataFrame([{'Name': 'Pinda Yaara', 'Marks': 57}])
df = pd.concat([df, new_row], ignore_index=True)
# Create new columns
df["Grade"] = df["Marks"] / 25
df.loc[df["Marks"] >= 95, "Status"] = "Excellent"
df.loc[df["Marks"] < 95, "Status"] = "Good"
df.loc[df["Honor roll"] == True, "PerformanceScore"] = df["Marks"] * 1
df.loc[df["Honor roll"] == False, "PerformanceScore"] = df["Marks"] * 0.9
# Rename the column
df.rename(columns = {"Grade": "GPA"}, inplace = True)
df
# Runnung "apply" on a series
df["Name"].apply(len)
def update_name(name):
    return name.upper()
df["Name"].apply(update_name)
df["Name"] = df["Name"].apply(lambda x : x.upper())
# running "apply" on a dataframe
df.apply(pd.Series.min)
# running "map"
df["Name"].map(len)
df["Name"].map(str.lower)
df["Name"].map({"Ajit" : "Pinda", "Hamza" : "Alam"})
# using "replace": wont put Null for values not assigned
df["Name"].replace({"Ajit" : "Pinda", "Hamza" : "Alam"})
# Removing the Status column
df.drop(columns = "Status", inplace = True)
# add new columns 
df[["first_name", "last_name"]] = df["Name"].str.split(" ", expand = True)
# Removing a row
df.drop(index = 3)
# Sorting by last name
df = df.sort_values(by = "last_name", ascending = False)
# Handling missing values
df.dropna(axis = 'index', how = 'all', subset = ["Name"])
# Check for missing values
df.isna()
# Fill missing values with a specific value
df["Marks"].fillna(df["Marks"].mean(), inplace = True)
# Convert Marks to float
df["Marks"] = df["Marks"].astype(float)
# Check data types
df.dtypes
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6396\1356902800.py:84: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Marks"].fillna(df["Marks"].mean(), inplace = True)
#             Name  Marks Honor roll   GPA  PerformanceScore first_name  \
# 4    PINDA YAARA   57.0        NaN  2.28               NaN      PINDA
# 2    JASSI SINGH   92.0      False  3.68              82.8      JASSI
# 3  JAMEEL JAMALI   99.0       True  3.96              99.0     JAMEEL
# 0     AJIT DOVAL   90.0      False  3.60              81.0       AJIT
# 1      HAMZA ALI   95.0       True  3.80              95.0      HAMZA
#
#   last_name
# 4     YAARA
# 2     SINGH
# 3    JAMALI
# 0     DOVAL
# 1       ALI

# %%
import pandas as pd
# Define custom NA values
na_vals = ["Missing", "NA"]
# Load the dataset with specified NA values
df = pd.read_csv('survey_results_public.csv', index_col = 'ResponseId', keep_default_na=False, na_values=na_vals)
schema_df = pd.read_csv('survey_results_schema.csv', index_col = 'qname')
# number of rows and columns
df.shape   
# info about the dataset
df.info()
# to see a set amount of columns
pd.set_option('display.max_columns', 25)
# to see a set amount of columns
pd.set_option('display.max_rows', 25)
df
# see the first n rows
display(df.head())
# see the last n rows
df.tail()
# to see how many rows have a particular value for the selected column
df.Age.value_counts()
# all columns for the first row
df.loc[0]
# find a specific column for a specific row
df.loc[0, 'Age']
df.loc[[0,1,2,3], 'Age']
# to sort the index
schema_df.sort_index(inplace = True)
df.loc[0 : 5]
# know the meaning of column name from schema CSV
schema_df.loc["ConvertedCompYearly", "question"]
# Filtering based on salary
high_salary = df["ConvertedCompYearly"] > 70000
df.loc[high_salary, ["Country",  "LanguageChoice" ,"ConvertedCompYearly", "WorkExp", "YearsCode"]]
# Filtering based on Country
countries = ["India", "Pakistan", "Canada"]
filt = df["Country"].isin(countries)
df.loc[filt, ["Country","ConvertedCompYearly", "WorkExp", "YearsCode"]]
# To look for a particular country
df[df["Country"] == "Germany"]
df.rename(columns = {"ConvertedCompYearly" : "SalaryUSD"}, inplace = True)
df['AIAgentChange'] = df['AIAgentChange'].map({"Yes":True,"No":False})
df.sort_values(by = ["Country", "SalaryUSD"], ascending = [True, False], inplace = True)
df[["Country", "SalaryUSD"]].head(50)
# Top 10 Largest salaries
df["SalaryUSD"].nlargest(10)
df.nlargest(10, "SalaryUSD")
# Median of all salaries
df["ConvertedCompYearly"].median()
# Median of all numeric values
df.median(numeric_only = True)
# to get different functions
df.describe()
df["Age"].describe()
# How many people answered what
df["MainBranch"].value_counts()
# what percentage of people answered what
df["SOAccount"].value_counts(normalize = True)
# Grouping by Country
country_grp = df.groupby("Country")
country_grp.get_group("Netherlands")
# finding different ages in a particular country
df.loc[df["Country"] == "India"]["Age"].value_counts()
# Number of people with SOAccount in each country
country_grp["SOAccount"].value_counts().head(50)
# Number of people with SOAccount in India
country_grp["SOAccount"].value_counts().loc["India"]
country_grp["ConvertedCompYearly"].median().loc[["India", "United States of America", "Pakistan", "France", "Germany"]]
# To run multiple aggregate functions
country_grp["ConvertedCompYearly"].agg(['median', 'mean']).loc[["India", "United States of America", "Pakistan", "France", "Germany"]]
# Number of people who have worked with Python in each country using filtering
df.loc[df["Country"] == "India"]["LanguageHaveWorkedWith"].str.contains("Python").sum()
# Number of people who have worked with Python in each country using grouping
country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
# Percentage of people who have worked with Python in each country using grouping
country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").value_counts(normalize = True) * 100).sort_values(ascending = False)
# Percentage of people who have worked with Python in a specific country using grouping
country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").value_counts(normalize = True) * 100).loc["Canada"]
# Unique values in YearsCode column
df["YearsCode"].unique()
# Mean of all numeric values
df["YearsCode"].mean()
# Median of all numeric values
df["YearsCode"].median()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10796\499041962.py:5: DtypeWarning: Columns (0: AIThreat, 1: DatabaseWantEntry, 2: DevEnvWantEntry, 3: SOTagsWant Entry, 4: OpSysPersonal use, 5: CommPlatformHaveWorkedWith, 6: CommPlatformWantEntr, 7: AIModelsChoice, 8: SOComm, 9: AIAgentOrchWrite, 10: AIAgentExternal) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('survey_results_public.csv', index_col = 'ResponseId', keep_default_na=False, na_values=na_vals)
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 1 to 49191
# Columns: 171 entries, MainBranch to JobSat
# dtypes: float64(52), str(119)
# memory usage: 64.2 MB
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
# 3                                         None of the above     10.0
# 4                                         None of the above      4.0
# 5           Caring for dependents (children, elderly, etc.)     21.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 1                         AI CodeGen tools or AI-enabled apps       14.0
# 2                         AI CodeGen tools or AI-enabled apps       10.0
# 3           AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 5           Technical documentation (is generated for/by t...       22.0
#
#                          DevType  ... AIAgentKnowledge AIAgentKnowWrite  \
# ResponseId                        ...
# 1              Developer, mobile  ...              NaN              NaN
# 2            Developer, back-end  ...              NaN              NaN
# 3           Developer, front-end  ...            Redis              NaN
# 4            Developer, back-end  ...              NaN              NaN
# 5            Engineering manager  ...              NaN              NaN
#
#            AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure  \
# ResponseId
# 1                     Vertex AI              NaN                  NaN
# 2                           NaN              NaN                  NaN
# 3                           NaN              NaN                  NaN
# 4                           NaN              NaN                  NaN
# 5                           NaN              NaN                  NaN
#
#             AIAgentObsWrite                                   AIAgentExternal  \
# ResponseId
# 1                       NaN                                           ChatGPT
# 2                       NaN                                               NaN
# 3                       NaN  ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 4                       NaN                               ChatGPT;Claude Code
# 5                       NaN                                               NaN
#
#             AIAgentExtWrite  \
# ResponseId
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
#
#                                                       AIHuman  \
# ResponseId
# 1                             When I don’t trust AI’s answers
# 2           When I don’t trust AI’s answers;When I want to...
# 3           When I don’t trust AI’s answers;When I want to...
# 4           When I don’t trust AI’s answers;When I want to...
# 5                             When I don’t trust AI’s answers
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                       61256.0    10.0
# 2                      104413.0     9.0
# 3                       53061.0     8.0
# 4                       36197.0     6.0
# 5                       60000.0     7.0
#
# [5 rows x 171 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: range.index(x): x not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 23
#      21 df.Age.value_counts()
#      22 # all columns for the first row
# ---> 23 df.loc[0]
#      24 # find a specific column for a specific row
#      25 df.loc[0, 'Age']
#
# File c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1449, in _LocIndexer._getitem_axis(self, key, axis)
#    1447 # fall thru to straight lookup
#    1448 self._validate_key(key, axis)
# -> 1449 return self._get_label(key, axis=axis)
#
# File c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1399, in _LocIndexer._get_label(self, label, axis)
#    1397 def _get_label(self, label, axis: AxisInt):
#    1398     # GH#5567 this will fail if the label is not present in the axis.
# -> 1399     return self.obj.xs(label, axis=axis)
#
# File c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4253, in NDFrame.xs(self, key, axis, level, drop_level)
#    4251             new_index = index[loc]
#    4252 else:
# -> 4253     loc = index.get_loc(key)
#    4255     if isinstance(loc, np.ndarray):
#    4256         if loc.dtype == np.bool_:
#
# File c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\range.py:523, in RangeIndex.get_loc(self, key)
#     521         return self._range.index(new_key)
#     522     except ValueError as err:
# --> 523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
#     525     raise KeyError(key)
#
# KeyError: 0
